# %% [markdown]
# This is the Python code I will use to clean the Sales dataset in this project, and I will be using Pandas Library. The dataset is from Kaggle and this is the link to access it:  "Retail Insights: A Comprehensive Sales Dataset" https://www.kaggle.com/datasets/rajneesh231/retail-insights-a-comprehensive-sales-dataset/data

# %%
 # Import library

# %%
import pandas as pd

# %%
# Import data as a pandas dataframe

# %%
sales_df = pd.read_csv('/Users/dianemireillekonan/Python files/Sales_data.csv')

# %%
# Explore the dataframe using head and info functions

# %%
sales_df.head(5)
# Out:
#   Order No  Order Date           Customer Name  \
# 0   4293-1  02-09-2014        Vivek Sundaresam
# 1   5001-1  24-10-2015          Shahid Hopkins
# 2   5004-1  13-03-2014           Dennis Pardue
# 3   5009-1  18-02-2013              Sean Wendt
# 4   5010-1  13-09-2014  Christina Vanderzanden
#
#                           Address       City State   Customer Type  \
# 0  152 Bunnerong Road,Eastgardens     Sydney   NSW  Small Business
# 1   438 Victoria Avenue,Chatswood     Sydney   NSW       Corporate
# 2        412 Brunswick St,Fitzroy  Melbourne   VIC        Consumer
# 3        145 Ramsay St,Haberfield     Sydney   NSW  Small Business
# 4          188 Pitt Street,Sydney     Sydney   NSW  Small Business
#
#   Account Manager Order Priority  \
# 0    Tina Carlton       Critical
# 1    Natasha Song         Medium
# 2    Connor Betts  Not Specified
# 3     Phoebe Gour       Critical
# 4    Tina Carlton  Not Specified
#
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order No           5000 non-null   object
#  1   Order Date         5000 non-null   object
#  2   Customer Name      5000 non-null   object
#  3   Address            4999 non-null   object
#  4   City               5000 non-null   object
#  5   State              5000 non-null   object
#  6   Customer Type      5000 non-null   object
#  7   Account Manager    5000 non-null   object
#  8   Order Priority     5000 non-null   object
#  9   Product Name       5000 non-null   object
#  10  Product Category   5000 non-null   object
#  11  Product Container  5000 non-null   object
#  12  Ship Mode          5000 non-null   object
#  13  Ship Date          5000 non-null   object
#  14  Cost Price         5000 non-null   object
#  15  Retail Price       5000 non-null   object
# ...

# %%
# Check null values

# %%
sales_df.isnull().any()
# Out:
# Order No             False
# Order Date           False
# Customer Name        False
# Address               True
# City                 False
# State                False
# Customer Type        False
# Account Manager      False
# Order Priority       False
# Product Name         False
# Product Category     False
# Product Container    False
# Ship Mode            False
# Ship Date            False
# Cost Price           False
# Retail Price         False
# Profit Margin        False
# Order Quantity        True
# Sub Total            False
# Discount %           False
# Discount $           False
# Order Total          False
# Shipping Cost        False
# Total                False
# dtype: bool

# %% [markdown]
# Since we have nulls values in Address and Order Quantity columns, let's find the rows with missing values.

# %%
sales_df[sales_df['Address'].isna()==1]
# Out:
#      Order No  Order Date Customer Name Address    City State   Customer Type  \
# 4354   6384-1  27-04-2016  Patt Bawkins     NaN  Sydney   NSW  Small Business
#
#      Account Manager Order Priority              Product Name  ... Cost Price  \
# 4354    Tina Carlton           High  HFX LaserJet 3310 Copier  ...    $377.99
#
#      Retail Price Profit Margin Order Quantity  Sub Total Discount %  \
# 4354      $599.99       $222.00           47.0  $9,599.84         0%
#
#      Discount $  Order Total Shipping Cost      Total
# 4354      $0.00    $9,599.84        $24.49  $9,624.33
#
# [1 rows x 24 columns]

# %%
sales_df[sales_df['Order Quantity'].isna()==1]
# Out:
#      Order No  Order Date Customer Name                  Address    City  \
# 1411   5428-1  25-02-2014   Jhrip Luxen  4A Lyons St,Strathfield  Sydney
#
#      State Customer Type Account Manager Order Priority  \
# 1411   NSW   Home Office    Tina Carlton           High
#
#                  Product Name  ... Cost Price Retail Price Profit Margin  \
# 1411  Creator Colored Pencils  ...      $1.57        $3.28         $1.71
#
#      Order Quantity Sub Total Discount % Discount $  Order Total  \
# 1411            NaN    $85.28         4%      $6.82       $78.46
#
#      Shipping Cost   Total
# 1411         $0.98  $79.44
#
# [1 rows x 24 columns]

# %% [markdown]
# Replace the address missing value with unknown as it will not be as relevant since we have city and state columns already.

# %%
sales_df['Address'] = sales_df['Address'].fillna('Unknown')

# %%
sales_df[sales_df['Address']== 'Unknown']
# Out:
#      Order No  Order Date Customer Name  Address    City State  \
# 4354   6384-1  27-04-2016  Patt Bawkins  Unknown  Sydney   NSW
#
#        Customer Type Account Manager Order Priority              Product Name  \
# 4354  Small Business    Tina Carlton           High  HFX LaserJet 3310 Copier
#
#       ... Cost Price Retail Price Profit Margin Order Quantity  Sub Total  \
# 4354  ...    $377.99      $599.99       $222.00           47.0  $9,599.84
#
#      Discount % Discount $  Order Total Shipping Cost      Total
# 4354         0%      $0.00    $9,599.84        $24.49  $9,624.33
#
# [1 rows x 24 columns]

# %%
# Now let's replace the Order Quantity missing value with the column mean

# %%
sales_df['Order Quantity'] = sales_df['Order Quantity'].fillna(sales_df['Order Quantity'].mean())

# %%
sales_df[sales_df['Customer Name']== 'Jhrip Luxen']
# Out:
#      Order No  Order Date Customer Name                  Address    City  \
# 1411   5428-1  25-02-2014   Jhrip Luxen  4A Lyons St,Strathfield  Sydney
#
#      State Customer Type Account Manager Order Priority  \
# 1411   NSW   Home Office    Tina Carlton           High
#
#                  Product Name  ... Cost Price Retail Price Profit Margin  \
# 1411  Creator Colored Pencils  ...      $1.57        $3.28         $1.71
#
#      Order Quantity Sub Total Discount % Discount $  Order Total  \
# 1411      26.483097    $85.28         4%      $6.82       $78.46
#
#      Shipping Cost   Total
# 1411         $0.98  $79.44
#
# [1 rows x 24 columns]

# %%
# Add a space after each comma in the 'Address' column

# %%
sales_df['Address'] = sales_df['Address'].str.replace(r",(\S)", r", \1", regex=True)

# %%
sales_df
# Out:
#      Order No  Order Date           Customer Name  \
# 0      4293-1  02-09-2014        Vivek Sundaresam
# 1      5001-1  24-10-2015          Shahid Hopkins
# 2      5004-1  13-03-2014           Dennis Pardue
# 3      5009-1  18-02-2013              Sean Wendt
# 4      5010-1  13-09-2014  Christina Vanderzanden
# ...       ...         ...                     ...
# 4995   6831-1  02-11-2016           Roland Murray
# 4996   6847-1  16-12-2015          Patrick OBrill
# 4997   6922-1  28-09-2016            Troy Staebel
# 4998   6939-1  18-06-2016             Shaun Weien
# 4999   6980-1  12-08-2015          Nora Pelletier
#
#                                    Address       City State   Customer Type  \
# 0          152 Bunnerong Road, Eastgardens     Sydney   NSW  Small Business
# 1           438 Victoria Avenue, Chatswood     Sydney   NSW       Corporate
# 2                412 Brunswick St, Fitzroy  Melbourne   VIC        Consumer
# ...

# %%
# Check for any duplicates values

# %%
sales_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
# Check variables datatypes

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order No           5000 non-null   object
#  1   Order Date         5000 non-null   object
#  2   Customer Name      5000 non-null   object
#  3   Address            5000 non-null   object
#  4   City               5000 non-null   object
#  5   State              5000 non-null   object
#  6   Customer Type      5000 non-null   object
#  7   Account Manager    5000 non-null   object
#  8   Order Priority     5000 non-null   object
#  9   Product Name       5000 non-null   object
#  10  Product Category   5000 non-null   object
#  11  Product Container  5000 non-null   object
#  12  Ship Mode          5000 non-null   object
#  13  Ship Date          5000 non-null   object
#  14  Cost Price         5000 non-null   object
#  15  Retail Price       5000 non-null   object
# ...

# %%
# Modify the date columns to datetime data type to ensure consistency

# %%
sales_df['Order Date'] = pd.to_datetime(sales_df['Order Date'], dayfirst = True)

# %%
sales_df['Ship Date'] = pd.to_datetime(sales_df['Ship Date'], dayfirst = True)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order No           5000 non-null   object
#  1   Order Date         5000 non-null   datetime64[ns]
#  2   Customer Name      5000 non-null   object
#  3   Address            5000 non-null   object
#  4   City               5000 non-null   object
#  5   State              5000 non-null   object
#  6   Customer Type      5000 non-null   object
#  7   Account Manager    5000 non-null   object
#  8   Order Priority     5000 non-null   object
#  9   Product Name       5000 non-null   object
#  10  Product Category   5000 non-null   object
#  11  Product Container  5000 non-null   object
#  12  Ship Mode          5000 non-null   object
#  13  Ship Date          5000 non-null   datetime64[ns]
#  14  Cost Price         5000 non-null   object
# ...

# %% [markdown]
# Some numerical columns have an object datatype. To better perform our analysis, let's modify "cost" related columns to a float datatype. First, I will remove the dollar signs and commas then convert.

# %% [markdown]
# sales_df['Cost Price'] = sales_df['Cost Price'].replace({'\$': ''}, regex=True).astype(float)

# %%
sales_df['Retail Price'] = sales_df['Retail Price'].replace({'\$': ''}, regex=True).astype(float)

# %%
sales_df['Profit Margin'] = sales_df['Profit Margin'].replace({'\$': ''}, regex=True).astype(float)

# %%
sales_df['Sub Total'] = sales_df['Sub Total'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
sales_df['Discount %'] = sales_df['Discount %'].replace({'\%': ''}, regex=True).astype(float)

# %%
sales_df['Discount $'] = sales_df['Discount $'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
sales_df['Order Total'] = sales_df['Order Total'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
sales_df['Shipping Cost'] = sales_df['Shipping Cost'].replace({'\$': ''}, regex=True).astype(float)

# %%
sales_df['Total'] = sales_df['Total'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order No           5000 non-null   object
#  1   Order Date         5000 non-null   datetime64[ns]
#  2   Customer Name      5000 non-null   object
#  3   Address            5000 non-null   object
#  4   City               5000 non-null   object
#  5   State              5000 non-null   object
#  6   Customer Type      5000 non-null   object
#  7   Account Manager    5000 non-null   object
#  8   Order Priority     5000 non-null   object
#  9   Product Name       5000 non-null   object
#  10  Product Category   5000 non-null   object
#  11  Product Container  5000 non-null   object
#  12  Ship Mode          5000 non-null   object
#  13  Ship Date          5000 non-null   datetime64[ns]
#  14  Cost Price         5000 non-null   float64
# ...

# %%
# Use the describe() function to see summary statistics

# %%
sales_df.describe()
# Out:
#                        Order Date                      Ship Date   Cost Price  \
# count                        5000                           5000  5000.000000
# mean   2015-02-03 19:21:30.240000  2015-02-05 15:24:46.079999744    20.394022
# min           2013-02-11 00:00:00            2013-02-12 00:00:00     0.240000
# 25%           2014-01-10 00:00:00            2014-01-11 00:00:00     1.840000
# 50%           2015-02-04 00:00:00            2015-02-10 00:00:00     3.500000
# 75%           2016-02-10 00:00:00            2016-02-11 00:00:00     8.845000
# max           2017-02-07 00:00:00            2017-02-07 00:00:00   377.990000
# std                           NaN                            NaN    57.137204
#
#        Retail Price  Profit Margin  Order Quantity     Sub Total   Discount %  \
# count   5000.000000     5000.00000     5000.000000   5000.000000  5000.000000
# mean      38.287266       17.99606       26.483097    783.586770     5.033800
# ...

# %%
# Specify the columns to check for outliers

# %%
columns_to_check = ['Cost Price', 'Retail Price', 'Profit Margin', 'Sub Total', 'Discount $', 'Order Total', 'Total']

# %%
# Calculate Q1, Q3, and IQR for the specified columns

# %%
Q1 = sales_df[columns_to_check].quantile(0.25)

# %%
Q3 = sales_df[columns_to_check].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
# Define outliers bound

# %%
lower_bound = Q1 - 1.5 * IQR

# %%
upper_bound = Q3 + 1.5 * IQR

# %%
# Filter out outliers

# %%
filtered_sales = sales_df[~((sales_df[columns_to_check] < lower_bound) | (sales_df[columns_to_check] > upper_bound)).any(axis=1)].copy()

# %%
filtered_sales.head(10)
# Out:
#    Order No Order Date           Customer Name  \
# 1    5001-1 2015-10-24          Shahid Hopkins
# 3    5009-1 2013-02-18              Sean Wendt
# 4    5010-1 2014-09-13  Christina Vanderzanden
# 5    5011-1 2013-11-24          Patrick OBrill
# 6    5012-1 2014-09-07            Eugene Moren
# 7    5012-1 2015-01-28       Phillip Flathmann
# 8    5014-1 2014-06-08                John Lee
# 11   5016-1 2013-02-11            Alex Russell
# 13   5019-1 2013-11-18       Phillip Flathmann
# 16   5020-1 2015-05-11            Bill Stewart
#
#                                               Address       City State  \
# 1                      438 Victoria Avenue, Chatswood     Sydney   NSW
# 3                           145 Ramsay St, Haberfield     Sydney   NSW
# 4                             188 Pitt Street, Sydney     Sydney   NSW
# 5                      53 Riley Street, Woolloomooloo     Sydney   NSW
# 6                        85-113 Dunning Ave, Rosebery     Sydney   NSW
# ...

# %%
# Sort the dataset by the Order Date column

# %%
filtered_sales.sort_values(by= ['Order Date'], inplace= True)

# %%
filtered_sales
# Out:
#      Order No Order Date   Customer Name  \
# 1035   5330-1 2013-02-11   Patrick Jones
# 2401   5753-1 2013-02-11   Thomas Boland
# 2620   5847-1 2013-02-11    Alex Russell
# 2792   5916-1 2013-02-11     Claire Good
# 11     5016-1 2013-02-11    Alex Russell
# ...       ...        ...             ...
# 4373   6387-2 2017-02-05      Art Foster
# 3203   6059-1 2017-02-07       Max Jones
# 4168   6332-1 2017-02-07   Cindy Chapman
# 4110   6324-1 2017-02-07  MaryBeth Skach
# 4412   6400-1 2017-02-07   Theresa Swint
#
#                                      Address       City State Customer Type  \
# 1035                 221 Barkly St, St Kilda  Melbourne   VIC      Consumer
# 2401  3/219 Canley Vale Road, Canley Heights     Sydney   NSW     Corporate
# 2620         99 Lygon Street, East Brunswick  Melbourne   VIC     Corporate
# 2792       7/370-374 Victoria Ave, Chatswood     Sydney   NSW     Corporate
# 11           99 Lygon Street, East Brunswick  Melbourne   VIC      Consumer
# ...

# %%
# Reset the index

# %%
filtered_sales.reset_index(drop= True, inplace= True)

# %%
filtered_sales
# Out:
#      Order No Order Date   Customer Name  \
# 0      5330-1 2013-02-11   Patrick Jones
# 1      5753-1 2013-02-11   Thomas Boland
# 2      5847-1 2013-02-11    Alex Russell
# 3      5916-1 2013-02-11     Claire Good
# 4      5016-1 2013-02-11    Alex Russell
# ...       ...        ...             ...
# 3794   6387-2 2017-02-05      Art Foster
# 3795   6059-1 2017-02-07       Max Jones
# 3796   6332-1 2017-02-07   Cindy Chapman
# 3797   6324-1 2017-02-07  MaryBeth Skach
# 3798   6400-1 2017-02-07   Theresa Swint
#
#                                      Address       City State Customer Type  \
# 0                    221 Barkly St, St Kilda  Melbourne   VIC      Consumer
# 1     3/219 Canley Vale Road, Canley Heights     Sydney   NSW     Corporate
# 2            99 Lygon Street, East Brunswick  Melbourne   VIC     Corporate
# 3          7/370-374 Victoria Ave, Chatswood     Sydney   NSW     Corporate
# 4            99 Lygon Street, East Brunswick  Melbourne   VIC      Consumer
# ...

# %% [markdown]
# Let's create a new column to store the cumulative revenue that will be used in visualization

# %%
filtered_sales['Cumulative Revenue'] = filtered_sales['Total'].cumsum()
# Out:
#      Order No Order Date   Customer Name  \
# 0      5330-1 2013-02-11   Patrick Jones
# 1      5753-1 2013-02-11   Thomas Boland
# 2      5847-1 2013-02-11    Alex Russell
# 3      5916-1 2013-02-11     Claire Good
# 4      5016-1 2013-02-11    Alex Russell
# ...       ...        ...             ...
# 3791   6582-1 2017-02-05      Art Foster
# 3796   6332-1 2017-02-07   Cindy Chapman
# 3797   6324-1 2017-02-07  MaryBeth Skach
# 3795   6059-1 2017-02-07       Max Jones
# 3798   6400-1 2017-02-07   Theresa Swint
#
#                                      Address       City State Customer Type  \
# 0                    221 Barkly St, St Kilda  Melbourne   VIC      Consumer
# 1     3/219 Canley Vale Road, Canley Heights     Sydney   NSW     Corporate
# 2            99 Lygon Street, East Brunswick  Melbourne   VIC     Corporate
# 3          7/370-374 Victoria Ave, Chatswood     Sydney   NSW     Corporate
# 4            99 Lygon Street, East Brunswick  Melbourne   VIC      Consumer
# ...

# %%
filtered_sales

# %% [markdown]
# Export the cleaned dataset to my file path for visualization in Power BI and Machine Learning (Clustering) in R.

# %%
filtered_sales.to_csv('/Users/dianemireillekonan/Python files/Cleaned_Sales_data.csv', index = False)
